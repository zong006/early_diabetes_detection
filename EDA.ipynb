# %%
import pandas as pd
import numpy as np

# %%
file_path = "../data/diabetes_risk_prediction_dataset.csv"

df = pd.read_csv(file_path)

# %% [markdown]
# - Age: Age of the individual (1.20-65).
# - Sex: Gender of the individual (1. Male, 2. Female).
# - Polyuria: Presence of excessive urination (1. Yes, 2. No).
# - Polydipsia: Excessive thirst (1. Yes, 2. No).
# - Sudden Weight Loss: Abrupt weight loss (1. Yes, 2. No).
# - Weakness: Generalized weakness (1. Yes, 2. No).
# - Polyphagia: Excessive hunger (1. Yes, 2. No).
# - Genital Thrush: Presence of genital thrush (1. Yes, 2. No).
# - Visual Blurring: Blurring of vision (1. Yes, 2. No).
# - Itching: Presence of itching (1. Yes, 2. No).
# - Irritability: Display of irritability (1. Yes, 2. No).
# - Delayed Healing: Delayed wound healing (1. Yes, 2. No).
# - Partial Paresis: Partial loss of voluntary movement (1. Yes, 2. No).
# - Muscle Stiffness: Presence of muscle stiffness (1. Yes, 2. No).
# - Alopecia: Hair loss (1. Yes, 2. No).
# - Obesity: Presence of obesity (1. Yes, 2. No).
#
#
# - Class: Diabetes classification (1. Positive, 2. Negative).
#
#
# All categorical variables are nominal

# %%
df
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0     40    Male       No        Yes                 No      Yes         No
# 1     58    Male       No         No                 No      Yes         No
# 2     41    Male      Yes         No                 No      Yes        Yes
# 3     45    Male       No         No                Yes      Yes        Yes
# 4     60    Male      Yes        Yes                Yes      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 515   39  Female      Yes        Yes                Yes       No        Yes
# 516   48  Female      Yes        Yes                Yes      Yes        Yes
# 517   58  Female      Yes        Yes                Yes      Yes        Yes
# 518   32  Female       No         No                 No      Yes         No
# 519   42    Male       No         No                 No       No         No
#
# ...

# %%
# df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 520 non-null    int64
#  1   Gender              520 non-null    object
#  2   Polyuria            520 non-null    object
#  3   Polydipsia          520 non-null    object
#  4   sudden weight loss  520 non-null    object
#  5   weakness            520 non-null    object
#  6   Polyphagia          520 non-null    object
#  7   Genital thrush      520 non-null    object
#  8   visual blurring     520 non-null    object
#  9   Itching             520 non-null    object
#  10  Irritability        520 non-null    object
#  11  delayed healing     520 non-null    object
#  12  partial paresis     520 non-null    object
#  13  muscle stiffness    520 non-null    object
#  14  Alopecia            520 non-null    object
# ...

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
df = pd.get_dummies(df, columns=categorical_columns, drop_first=True)

# %%
df
# Out:
#      Age  Gender_Male  Polyuria_Yes  Polydipsia_Yes  sudden weight loss_Yes  \
# 0     40            1             0               1                       0
# 1     58            1             0               0                       0
# 2     41            1             1               0                       0
# 3     45            1             0               0                       1
# 4     60            1             1               1                       1
# ..   ...          ...           ...             ...                     ...
# 515   39            0             1               1                       1
# 516   48            0             1               1                       1
# 517   58            0             1               1                       1
# 518   32            0             0               0                       0
# 519   42            1             0               0                       0
#
# ...

# %%
df["Gender_Male"].hist(by=df["class_Positive"], bins=10, figsize=(10, 6), alpha=0.5)
# Out:
# array([<AxesSubplot:title={'center':'0'}>,
#        <AxesSubplot:title={'center':'1'}>], dtype=object)

# %% [markdown]
# - Split between males and females amongst positive cases are quite even.
# - About 90% of negative cases are males.

# %%
df["class_Positive"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# The split between positive and negative cases are ~3:2. It is unbalanced, but not by a lot.

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(8, 6))
sns.boxplot(x=df['class_Positive'], y=df['Age'], data=df, width = 0.3)
# Out:
# <AxesSubplot:xlabel='class_Positive', ylabel='Age'>

# %% [markdown]
# The interquartile range for both positive and negative classes are similar, at ~20years. The range however, is much bigger in positive cases, where there are very old and very young people who have diabetes.

# %%
df["Age"].describe()
# Out:
# count    520.000000
# mean      48.028846
# std       12.151466
# min       16.000000
# 25%       39.000000
# 50%       47.500000
# 75%       57.000000
# max       90.000000
# Name: Age, dtype: float64

# %%
# df = df[~(df["Age"]>1.5*57)]

# %%
sns.violinplot(data=df,y=df["Age"], x=df["class_Positive"], hue=df["Gender_Male"], split=True)
plt.show()

# %% [markdown]
# More females tend to develop diabetes when they are younger compared to males, where there is are two peaks of female positive cases around ages 39 and 45, whilst for positive males there is a peak at around age 60.

# %%
corr_matrix = df.corr()

# Plot the correlation matrix using a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix - One-Hot Encoded Variables')
plt.show()

# %%
target_variable = 'class_Positive'
correlation_threshold = 0.4 

filtered_variables = corr_matrix[corr_matrix[target_variable] > correlation_threshold].index

print(f"Variables with correlation > {correlation_threshold} with '{target_variable}':")
print(filtered_variables)
# Out:
# Variables with correlation > 0.4 with 'class_Positive':
# Index(['Polyuria_Yes', 'Polydipsia_Yes', 'sudden weight loss_Yes',
#        'partial paresis_Yes', 'class_Positive'],
#       dtype='object')

# %% [markdown]
# The following variables are more correlated with being a positive case:
# - Polyuria_Yes
# - Polydipsia_Yes
#
# Nonetheless, correlation score of polyuria and polydipsia are quite high, at 0.6

# %%
from scipy.stats import chi2_contingency

contingency_table = pd.crosstab(df['Polyuria_Yes'], df['Polydipsia_Yes'])

chi2, p, _, _ = chi2_contingency(contingency_table)

print("Chi-square statistic:", chi2)
print("P-value:", p)
# Out:
# Chi-square statistic: 183.9333377690544
# P-value: 6.70908249587708e-42

# %% [markdown]
# A chi-squared test of independence tells us that the  p-value < 0.05, the null hypthesis that these are independent variables are rejected, and we conclude that there is a significant association between "Polyuria_Yes" and "Polydipsia_Yes". Nonetheless, it is unclear without more information on whether one of them are redudndant or not.

# %% [markdown]
# Overall observations from EDA:
#
# - Split between males and females amongst positive cases are quite even. About 90% of negative cases are males.
# - More females tend to develop diabetes when they are younger compared to males. Most females who develop diabetes are in their early 40s, whilst that for males is at the early 60s.
# - Having polyuria and/or polydipsia makes it more likely that there is diabetes due to the strong correlation between these two factors with having diabetes.
# - Other features with significant but less strong positive correlation with diabetes are having sudden weight loss,
